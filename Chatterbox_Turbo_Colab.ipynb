# %% [markdown]
# # ⚡ Chatterbox Turbo TTS
#
# This notebook installs and runs Chatterbox Turbo from your GitHub repository.
# It will generate a **public Gradio URL** that you can open to use the web UI.

# %%
# !git clone https://github.com/ai-pix/chatterbox-turbo.git
# %cd chatterbox-turbo

# %%
# !pip install -r requirements.txt
# !pip install -e .

# %%
# Run the application. A public Gradio link will appear below.
# !python run_turbo.py
